# %% [markdown]
# 00_count num

# %%
def main():
  lst:list[int] = list()
  while True:
      new = input("Enter a Number")
      if new == "":
          break
      lst.append(int(new))

  dct = dict()
  for i in lst:
      if i in dct:
          dct[i] += 1
      else:
          dct[i] = 1

  for i,k in dct.items():
      print(f"{i} appears {k} times in lst")

# This provided line is required at the end of
# Python file to call the main() function.
if __name__ == '__main__':
    main()
# Out:
# Enter a Number1
# Enter a Number2
# Enter a Number3
# Enter a Number4
# Enter a Number1
# Enter a Number
# 1 appears 2 times in lst
# 2 appears 1 times in lst
# 3 appears 1 times in lst
# 4 appears 1 times in lst

# %% [markdown]
# 01_phonebook.md

# %%
def main():
  phonebook = dict()
  while True:
    Name = input("Input a Name ")
    if Name == "":
      break
    Number = input("Input a Number ")
    phonebook[Name] = Number

  while True:
    search = input("Enter to Search a Phone Number")
    if search == "":
      break
    if search not in phonebook:
      print("Not Found")
      continue
    print(phonebook[search])


# This provided line is required at the end of
# Python file to call the main() function.
if __name__ == '__main__':
  main()
# Out:
# Input a Name AD
# Input a Number 213213
# Input a Name tre
# Input a Number 92138
# Input a Name hasd
# Input a Number 92139123
# Input a Name
# Enter to Search a Phone Numbertr
# Not Found
# Enter to Search a Phone Numbertre
# 92138
# Enter to Search a Phone Number

# %% [markdown]
# 02_pop_up_shop.md

# %%
def main():
    fruits = {'apple': 1.5, 'durian': 50, 'jackfruit': 80, 'kiwi': 1, 'rambutan': 1.5, 'mango': 5}

    total_cost = 0
    for fruit_name in fruits:
        price = fruits[fruit_name]
        amount_bought = int(input("How many (" + fruit_name + ") do you want to buy?: "))
        total_cost += (price * amount_bought)

    print("Your total is $" + str(total_cost))


# There is no need to edit code beyond this point

if __name__ == '__main__':
    main()
# Out:
# How many (apple) do you want to buy?: 21
# How many (durian) do you want to buy?: 32
# How many (jackfruit) do you want to buy?: 123
# How many (kiwi) do you want to buy?: 2134
# How many (rambutan) do you want to buy?: 214213
# How many (mango) do you want to buy?: 214231134213
# Your total is $1071156005990.0
