# %%
ADULT_AGE: int = 18

def is_adult(age: int)->str:
    return "True" if age >= ADULT_AGE else "False"

def main():
    age: int = int(input("How old is this person?: "))
    print(is_adult(age))

if __name__ == "__main__":
    main()
# Out:
# How old is this person?: 19
# True

# %%
def main():
    name : str = input("What's your name? ")
    print(greet(name))

def greet(name):
    return f"Greetings {name} !"

if __name__ == '__main__':
    main()
# Out:
# What's your name? Abubakar
# Greetings Abubakar !

# %%
def in_range(n, low, high):
    """
    Returns True if n is between low and high, inclusive.
    high is guaranteed to be greater than low.
    """
    if n >= low and n <= high:
        return True
    return "YO BRO"

def main():
    print(in_range(5, 1, 10))
    print(in_range(0, 1, 10))

if __name__ == '__main__':
    main()
# Out:
# True
# YO BRO

# %%
def main():
    fruit: str = input("Enter a fruit: ")
    stock = num_in_stock(fruit)
    if stock == 0:
        print("This fruit is not in stock.")
    else:
        print("This fruit is in stock! Here is how many:")
        print(stock)

def num_in_stock(fruit):
    if fruit == 'apple':
        return 2
    if fruit == 'durian':
        return 4
    if fruit == 'pear':
        return 1000
    else:
        return 0

if __name__ == '__main__':
    main()

# %%
def user_data():
    name = input("What is your first name?: ")
    email = input("What is your email address?: ")
    return {name:name,email:email}

def main():
    data = user_data()
    print("Received the following user data:", data)

if __name__ == '__main__':
    main()
# Out:
# What is your first name?: haha
# What is your email address?: haha
# Received the following user data: {'haha': 'haha'}

# %%
def main():
    sub_seven()

def sub_seven():
  try:
    num = int(input("Enter a number: "))
  except ValueError as e:
      print("Value error here")
  else:
      print(num - 7)



if __name__ == '__main__':
    main()
# Out:
# Enter a number: 0
# -7
