# %% [markdown]
# Adding Two Numbers:

# %%
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the second number: "))

sum:int = number1 + number2

print(f"Sum of first and second number is {sum}")
# Out:
# Enter the first number: 1
# Enter the second number: 1
# Sum of first and second number is 2

# %% [markdown]
# 02_agreement bot

# %%
def main():
    fav_ani = input("What is your favorite animal? ")
    print(f"Wow, {fav_ani} is my favorite too!")

# This provided line is required at the end of
# Python file to call the main() function.
if __name__ == '__main__':
    main()

# %% [markdown]
# Fahrenheit to Celcius

# %%
def main():
    degrees_fahrenheit:float  = float(input("enter Temperature in Fahrenheit: "))
    degrees_celcius:float = (degrees_fahrenheit - 32) * 5/9
    print(f"{degrees_fahrenheit} degrees Fahrenheit is {degrees_celcius} degrees Celcius")


# This provided line is required at the end of
# Python file to call the main() function.
if __name__ == '__main__':
    main()
# Out:
# enter Temperature in Fahrenheit: 120.3
# 120.3 degrees Fahrenheit is 49.05555555555556 degrees Celcius

# %% [markdown]
# How Old are they?

# %%
def main():
    Anton = 21
    Beth = 6
    Chen = 20
    Drew = Chen + Anton
    Ethan = Chen

    print(f"Anton is {Anton} years old")
    print(f"Beth is {Beth} years old")
    print(f"Chen is {Chen} years old")
    print(f"Drew is {Drew} years old")
    print(f"Ethan is {Ethan} years old")

# This provided line is required at the end of
# Python file to call the main() function.
if __name__ == '__main__':
    main()
# Out:
# Anton is 21 years old
# Beth is 6 years old
# Chen is 20 years old
# Drew is 41 years old
# Ethan is 20 years old

# %% [markdown]
# triangle Preimeter

# %%
def main():
    side1: float = float(input("What is the length of side 1? "))
    side2: float = float(input("What is the length of side 2? "))
    side3: float = float(input("What is the length of side 3? "))
    print(f"Triangle perimeter is {side1+side2+side3}")

# This provided line is required at the end of
# Python file to call the main() function.
if __name__ == '__main__':
    main()
# Out:
# What is the length of side 1? 1
# What is the length of side 2? 1
# What is the length of side 3? 1
# Triangle perimeter is 3.0

# %% [markdown]
# square Number

# %%
def main():
    num: float = float(input("Type a number to see its square: "))
    print(f"{num} squared is {num**2}")

# This provided line is required at the end of
# Python file to call the main() function.
if __name__ == '__main__':
    main()


if __name__ == '__main__':
    main()
